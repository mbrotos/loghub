# %%
import pandas as pd
import glob

# %%
structured_paths = sorted(glob.glob('./*/*_structured.csv'))
templates_paths = sorted(glob.glob('./*/*_templates.csv'))
templates_paths.pop(templates_paths.index('./HDFS/HDFS_templates.csv'))
templates_paths.pop(templates_paths.index('./BGL/BGL_templates.csv'))
# Out:
# './BGL/BGL_templates.csv'

# %%
paths = list(zip(structured_paths, templates_paths))
paths
# Out:
# [('./Android/Android_2k.log_structured.csv',
#   './Android/Android_2k.log_templates.csv'),
#  ('./Apache/Apache_2k.log_structured.csv',
#   './Apache/Apache_2k.log_templates.csv'),
#  ('./BGL/BGL_2k.log_structured.csv', './BGL/BGL_2k.log_templates.csv'),
#  ('./HDFS/HDFS_2k.log_structured.csv', './HDFS/HDFS_2k.log_templates.csv'),
#  ('./HPC/HPC_2k.log_structured.csv', './HPC/HPC_2k.log_templates.csv'),
#  ('./Hadoop/Hadoop_2k.log_structured.csv',
#   './Hadoop/Hadoop_2k.log_templates.csv'),
#  ('./HealthApp/HealthApp_2k.log_structured.csv',
#   './HealthApp/HealthApp_2k.log_templates.csv'),
#  ('./Linux/Linux_2k.log_structured.csv', './Linux/Linux_2k.log_templates.csv'),
#  ('./Mac/Mac_2k.log_structured.csv', './Mac/Mac_2k.log_templates.csv'),
#  ('./OpenSSH/OpenSSH_2k.log_structured.csv',
#   './OpenSSH/OpenSSH_2k.log_templates.csv'),
#  ('./OpenStack/OpenStack_2k.log_structured.csv',
#   './OpenStack/OpenStack_2k.log_templates.csv'),
#  ('./Proxifier/Proxifier_2k.log_structured.csv',
#   './Proxifier/Proxifier_2k.log_templates.csv'),
#  ('./Spark/Spark_2k.log_structured.csv', './Spark/Spark_2k.log_templates.csv'),
#  ('./Thunderbird/Thunderbird_2k.log_structured.csv',
#   './Thunderbird/Thunderbird_2k.log_templates.csv'),
#  ('./Windows/Windows_2k.log_structured.csv',
#   './Windows/Windows_2k.log_templates.csv'),
#  ('./Zookeeper/Zookeeper_2k.log_structured.csv',
#   './Zookeeper/Zookeeper_2k.log_templates.csv')]

# %%
template1 = pd.read_csv(paths[-2][1])
template1
# Out:
#    EventId                                      EventTemplate
# 0       E1  <*> Created NT transaction (seq <*>) result <*...
# 1       E2  <*> Creating NT transaction (seq <*>), objectn...
# 2       E3                                <*> CSI perf trace:
# 3       E4                <*> CSI Store <*> (<*>) initialized
# 4       E5  <*> IAdvancedInstallerAwareStore_ResolvePendin...
# 5       E6  <*> ICSITransaction::Commit calling IStorePend...
# 6       E7  <*> Performing <*> operations; <*> are not loc...
# 7       E8  <*> Store coherency cookie matches last scaven...
# 8       E9  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> CSI Transactio...
# 9      E10  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> CSI Transactio...
# 10     E11  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> PopulateCompon...
# 11     E12  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> PopulateCompon...
# 12     E13  <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize ...
# 13     E14  Disabling manifest caching, because the image ...
# 14     E15             Ending the TrustedInstaller main loop.
# 15     E16              Ending TrustedInstaller finalization.
# 16     E17            Ending TrustedInstaller initialization.
# 17     E18  Expecting attribute name [HRESULT = <*> - CBS_...
# 18     E19  Failed to create backup log cab. [HRESULT = <*...
# 19     E20  Failed to get next element [HRESULT = <*> - CB...
# 20     E21  Failed to internally open package. [HRESULT = ...
# 21     E22         Idle processing thread terminated normally
# 22     E23  Loaded Servicing Stack <*> with Core: <*>\cbsc...
# 23     E24  Loading offline registry hive: <*>, into regis...
# 24     E25  No startup processing required, TrustedInstall...
# 25     E26  NonStart: Checking to ensure startup processin...
# 26     E27  NonStart: Success, startup processing not requ...
# 27     E28                        Offline image is: read-only
# 28     E29  Read out cached package applicability for pack...
# 29     E30               Reboot mark refs incremented to: <*>
# 30     E31                              Reboot mark refs: <*>
# 31     E32                          Scavenge: Begin CSI Store
# 32     E33              Scavenge: Completed, disposition: <*>
# 33     E34                                   Scavenge: Starts
# 34     E35        Session: <*>_<*> initialized by client SPP.
# 35     E36  Session: <*>_<*> initialized by client Windows...
# 36     E37  SQM: Cleaning up report files older than <*> d...
# 37     E38  SQM: Failed to start standard sample upload. [...
# 38     E39  SQM: Failed to start upload with file pattern:...
# 39     E40  SQM: Initializing online with Windows opt-in: ...
# 40     E41  SQM: Queued <*> file(s) for upload with patter...
# 41     E42      SQM: Requesting upload of all unsent reports.
# 42     E43  SQM: Warning: Failed to upload all unsent repo...
# 43     E44           Starting the TrustedInstaller main loop.
# 44     E45            Starting TrustedInstaller finalization.
# 45     E46          Starting TrustedInstaller initialization.
# 46     E47      Startup processing thread terminated normally
# 47     E48      TrustedInstaller service starts successfully.
# 48     E49               Unloading offline registry hive: <*>
# 49     E50   Warning: Unrecognized packageExtended attribute.

# %%
def count_variables(eventTemplate):
    # This function counts the number of variables in the event template
    # The variables are represented by '<*>'
    # The function also revises the counts by enforing timestamp patterns to be counted as one variable
    replacements = [
        '<*>/<*>/<*>:<*>:<*>:<*>.<*>',
        'time=<*>,<*>,<*>,<*>,<*>,',
        '#<*> <*>:<*>:<*> EDT <*>',
        'seconds at <*>:<*>:<*> <*>',
        '[<*>:<*>:<*>.<*>]',
        '<*>:<*>:<*>.<*>',
        '<*>/<*>/<*> <*>:<*>:<*> ak Exp',
        'delay=<*>:<*>:<*>, xdelay=<*>:<*>:<*>'
    ]
    
    # Sort replacements by length of the pattern in descending order
    # This is to ensure that the longest pattern is replaced first
    replacements.sort(key=lambda x: len(x), reverse=True)
    
    occurrences = eventTemplate.count('<*>')
    
    for pattern in replacements:
        count = pattern.count('<*>')
        occurrences -= eventTemplate.count(pattern) * (count-1) # This is to avoid counting the same variable multiple times, instead we count it once
        eventTemplate = eventTemplate.replace(pattern, '') # Remove the pattern from the template, this is to avoid counting the same pattern multiple times
    
    return occurrences

# %%
structure1 = pd.read_csv(paths[-2][0])
structure1
# Out:
#       LineId        Date      Time Level Component  \
# 0          1  2016-09-28  04:30:30  Info       CBS
# 1          2  2016-09-28  04:30:31  Info       CSI
# 2          3  2016-09-28  04:30:31  Info       CSI
# 3          4  2016-09-28  04:30:31  Info       CSI
# 4          5  2016-09-28  04:30:31  Info       CBS
# ...      ...         ...       ...   ...       ...
# 1995    1996  2016-09-29  02:04:40  Info       CBS
# 1996    1997  2016-09-29  02:04:40  Info       CBS
# 1997    1998  2016-09-29  02:04:40  Info       CBS
# 1998    1999  2016-09-29  02:04:40  Info       CBS
# 1999    2000  2016-09-29  02:04:40  Info       CBS
#
#                                                 Content EventId  \
# 0     Loaded Servicing Stack v6.1.7601.23505 with Co...     E23
# 1     00000001@2016/9/27:20:30:31.455 WcpInitialize ...     E13
# 2     00000002@2016/9/27:20:30:31.458 WcpInitialize ...     E13
# 3     00000003@2016/9/27:20:30:31.458 WcpInitialize ...     E13
# 4               Ending TrustedInstaller initialization.     E17
# ...                                                 ...     ...
# 1995  Read out cached package applicability for pack...     E29
# 1996  Session: 30546354_3360174372 initialized by cl...     E36
# 1997  Read out cached package applicability for pack...     E29
# 1998  Session: 30546354_3363894584 initialized by cl...     E36
# 1999  Read out cached package applicability for pack...     E29
#
#                                           EventTemplate
# 0     Loaded Servicing Stack <*> with Core: <*>\cbsc...
# 1     <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize ...
# 2     <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize ...
# 3     <*>@<*>/<*>/<*>:<*>:<*>:<*>.<*> WcpInitialize ...
# 4               Ending TrustedInstaller initialization.
# ...                                                 ...
# 1995  Read out cached package applicability for pack...
# 1996  Session: <*>_<*> initialized by client Windows...
# 1997  Read out cached package applicability for pack...
# 1998  Session: <*>_<*> initialized by client Windows...
# 1999  Read out cached package applicability for pack...
#
# [2000 rows x 8 columns]

# %%
# get the counts of EventId from the structured data
event_counts = structure1['EventId'].value_counts()
event_counts
# Out:
# EventId
# E36    608
# E29    558
# E50    280
# E20    224
# E18    224
# E21     18
# E24      8
# E49      8
# E13      6
# E2       3
# E1       3
# E3       3
# E4       3
# E39      2
# E37      2
# E17      2
# E38      2
# E19      2
# E44      2
# E48      2
# E40      2
# E23      2
# E42      2
# E27      2
# E5       2
# E26      2
# E25      2
# E43      2
# E47      2
# E41      2
# E28      1
# E16      1
# E46      1
# E12      1
# E14      1
# E11      1
# E15      1
# E35      1
# E45      1
# E9       1
# E22      1
# E31      1
# E33      1
# E6       1
# E8       1
# E7       1
# E32      1
# E10      1
# E30      1
# E34      1
# Name: count, dtype: int64

# %%
template1['variables'] = template1['EventTemplate'].apply(count_variables)

# %%
# lets join the variables counts with the event counts
event_counts = event_counts.to_frame().reset_index()
event_counts.columns = ['EventId', 'count']
event_counts = event_counts.merge(template1[['EventId', 'variables']], on='EventId')
event_counts
# Out:
#    EventId  count  variables
# 0      E36    608          2
# 1      E29    558          3
# 2      E50    280          0
# 3      E20    224          1
# 4      E18    224          1
# 5      E21     18          1
# 6      E24      8          3
# 7      E49      8          1
# 8      E13      6          4
# 9       E2      3          3
# 10      E1      3          4
# 11      E3      3          1
# 12      E4      3          3
# 13     E39      2          3
# 14     E37      2          1
# 15     E17      2          0
# 16     E38      2          1
# 17     E19      2          1
# 18     E44      2          0
# 19     E48      2          0
# 20     E40      2          0
# 21     E23      2          2
# 22     E42      2          0
# 23     E27      2          0
# 24      E5      2          6
# 25     E26      2          0
# 26     E25      2          0
# 27     E43      2          1
# 28     E47      2          0
# 29     E41      2          3
# 30     E28      1          0
# 31     E16      1          0
# 32     E46      1          0
# 33     E12      1          2
# 34     E14      1          0
# 35     E11      1          2
# 36     E15      1          0
# 37     E35      1          2
# 38     E45      1          0
# 39      E9      1          3
# 40     E22      1          0
# 41     E31      1          1
# 42     E33      1          1
# 43      E6      1          2
# 44      E8      1          1
# 45      E7      1          3
# 46     E32      1          0
# 47     E10      1          7
# 48     E30      1          1
# 49     E34      1          0

# %%
loghub_variable_instance_counts = []

for structure_path, template_path in paths:
    structure = pd.read_csv(structure_path)
    template = pd.read_csv(template_path)
    dataset = structure_path.split('/')[1]
    
    # Count the number of variables in the event template
    template['unique_variables'] = template['EventTemplate'].apply(count_variables)

    # get the counts of EventId from the structured data
    event_counts = structure['EventId'].value_counts()
    event_counts = event_counts.to_frame().reset_index()
    event_counts.columns = ['EventId', 'instance_count']
    event_counts = event_counts.merge(template[['EventId', 'unique_variables']], on='EventId')
    event_counts['dataset'] = dataset

    loghub_variable_instance_counts.append(event_counts)

loghub_variable_instance_counts = pd.concat(loghub_variable_instance_counts)
loghub_variable_instance_counts
# Out:
#    EventId  instance_count  unique_variables    dataset
# 0     E126             200                15    Android
# 1     E103             199                 8    Android
# 2     E123             181                 0    Android
# 3      E65              85                 1    Android
# 4      E21              85                 2    Android
# ..     ...             ...               ...        ...
# 45     E21               1                 7  Zookeeper
# 46     E30               1                 2  Zookeeper
# 47     E48               1                 1  Zookeeper
# 48     E35               1                 5  Zookeeper
# 49     E34               1                 5  Zookeeper
#
# [1363 rows x 4 columns]

# %%
loghub_variable_instance_counts['percentage_total'] = loghub_variable_instance_counts['instance_count'] / 2000

# %%
# save the results
loghub_variable_instance_counts.to_csv('loghub_variable_instance_counts.csv', index=False)

# %%
def generate_dataset_summary_table(df):

    summary_df = (
        df.copy()
        .groupby('dataset')
        .agg(
            num_templates=('EventId', 'nunique'),
            avg_vars=('unique_variables', 'mean'),
            median_vars=('unique_variables', 'median'),
            min_vars=('unique_variables', 'min'),
            max_vars=('unique_variables', 'max'),
            std_vars=('unique_variables', 'std')
        )
        .reset_index()
    )
    summary_df['avg_vars'] = summary_df['avg_vars'].round(2)
    summary_df['std_vars'] = summary_df['std_vars'].round(2)

    # rename the columns
    summary_df.columns = [
        'Dataset',
        'Number of Templates',
        'Mean',
        'Median',
        'Minimum',
        'Maximum',
        'Standard Deviation'
    ]

    return summary_df

# %%
summary_table = generate_dataset_summary_table(loghub_variable_instance_counts)
summary_table
# Out:
#         Dataset  Number of Templates  Mean  Median  Minimum  Maximum  \
# 0       Android                  166  2.14     1.0        0       20
# 1        Apache                    6  1.50     1.5        1        2
# 2           BGL                  120  2.18     1.0        0       25
# 3          HDFS                   14  3.64     3.5        1        6
# 4           HPC                   46  1.24     1.0        0        9
# 5        Hadoop                  114  1.75     1.0        0       12
# 6     HealthApp                   75  1.32     1.0        0        8
# 7         Linux                  118  1.19     1.0        0       13
# 8           Mac                  341  3.06     1.0        0       36
# 9       OpenSSH                   27  2.07     2.0        0        4
# 10    OpenStack                   43  2.63     1.0        0       14
# 11    Proxifier                    8  4.50     4.5        2        6
# 12        Spark                   36  1.08     1.0        0        4
# 13  Thunderbird                  149  1.58     1.0        0       10
# 14      Windows                   50  1.40     1.0        0        7
# 15    Zookeeper                   50  1.82     1.0        0        7
#
#     Standard Deviation
# 0                 3.10
# 1                 0.55
# 2                 2.85
# 3                 1.34
# 4                 1.80
# 5                 2.24
# 6                 1.72
# 7                 1.65
# 8                 4.69
# 9                 1.27
# 10                2.55
# 11                1.31
# 12                1.13
# 13                1.99
# 14                1.62
# 15                1.73

# %%
# save the results
summary_table.to_csv('loghub_variable_instance_summary.csv', index=False)

# %%
# export the summary table to latex
summary_table.to_latex('loghub_variable_instance_summary.tex', index=False, caption='Summary of the number of variables in the LogHub datasets', label='tab:loghub_variable_instance_summary')
